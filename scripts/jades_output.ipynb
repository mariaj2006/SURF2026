# %%
# open data fits file
from astropy.table import Table
path = '/home/caltech-msanche3/data/JADES_fits_data.fits'

jades_output_tbl = Table.read(path,hdu='PHOTOZ',format='fits')
print(jades_output_tbl[55102])
# Out:
#   ID    z_spec  z_a     z_ml     chi_a          l68                u68                l95                u95                l99                u99         nfilt       z_peak            chi_peak         z025      z160      z500       z840      z975       Prob_gt_5      Prob_gt_6     Prob_gt_7          Prob_gt_8          Prob_gt_9         chisq_z_lt_7      z_chisq_z_lt_7      chisq_z_lt_6      z_chisq_z_lt_6      chisq_z_lt_5      z_chisq_z_lt_5      chisq_z_lt_4      z_chisq_z_lt_4      z_bins    Prob_z_bins
# ------ ------- ----- --------- --------- ------------------ ------------------ ------------------ ------------------ ------------------ ------------------ ----- ------------------ ------------------ --------- --------- ---------- --------- --------- ------------------ --------- ------------------ ------------------ ------------------ ------------------ ------------------ ------------------ ------------------ ------------------ ------------------ ------------------ ------------------ ------------ -----------
# 183348 -9999.0 14.38 14.377759 23.903345 14.312790729711253 14.962286019915561 14.109344175209708 15.094709084131084 13.938980026577223 15.133173970341979    19 14.380000114440918 23.903345108032227 14.110018 14.306202 14.6033945 14.953275 15.097244 0.9999999403953552       1.0 0.9999999403953552 0.9999999403953552 0.9999999403953552 169.43959045410156 3.8299999237060547 169.43959045410156 3.8299999237060547 169.43959045410156 3.8299999237060547 169.43959045410156 3.8299999237060547 0.35 .. 21.0  0.0 .. 0.0
