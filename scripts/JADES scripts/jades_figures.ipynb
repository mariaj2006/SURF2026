# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['text.usetex'] = True

# ADD THIS TO PAPER

x = np.linspace(5.5, 14, 10)
y = np.linspace(5.5, 14, 10)

# Main dataset
zspec_45 = [
    7.95,7.96,8.19,12.48,9.68,6.63,6.33,6.32,6.09,7.04,8.58,6.16,9.43,6.04,
    7.41,10.60,7.12,6.73,7.13,6.71
]
zphot_45 = [
    8.01, 8.11, 8.07, 13.34, 9.82, 6.57, 6.29, 6.30, 6.13, 7.05, 8.63, 6.22, 9.82, 6.87,
    7.61, 10.47, 7.36, 6.72, 7.21, 6.68
]
z_lo_45 = [
    0.062, 0.206, 0.077, 0.846, 0.16, 0.052, 0.06, 0.051, 0.048, 0.056, 0.081, 0.061, 0.1, 0.053,
    0.071, 0.091, 0.085, 0.071, 0.074, 0.033
]
z_hi_45 = [
    0.076, 0.119, 0.063, 0.378, 0.128, 0.051, 0.064, 0.062, 0.048, 0.055, 0.066, 0.063, 0.095, 0.053,
    0.046, 0.097, 0.126, 0.034, 0.07, 0.072
]

err_45 = [z_lo_45, z_hi_45]


# Calculate fractional error
eazy_err = [(zs - zp) / (1 + zs) for zs, zp in zip(zspec_45, zphot_45)]


fig, (ax1, ax2) = plt.subplots(
    2, 1, 
    figsize=(7, 7), 
    sharex=True, 
    gridspec_kw={'hspace': 0, 'height_ratios': [3, 1]}
)

# Top Subplot: z_phot vs z_spec
ax1.errorbar(zspec_45, zphot_45, yerr=err_45, fmt='s', c='#E75480', ms=4, elinewidth=1, alpha=0.8, label="45K Templates",markeredgecolor='k',capsize=4,ecolor='k')
ax1.plot(x, y, alpha=0.3, c='k', linestyle='--', label=r'$z_{phot} = z_{spec}$ line')

ax1.set_xlim(5.5, 14)
ax1.set_ylim(5.5, 14)
ax1.set_ylabel(r'$z_{phot}$',fontsize=18)
ax1.set_title(r'Comparison of photometric redshifts vs. spectroscopic redshifts')

# Enable minor ticks and set ticks all around (top, bottom, left, right)
ax1.minorticks_on()
ax1.tick_params(axis='both', which='both', direction='in', top=True, right=True, labelsize=10)
ax1.grid(True, linestyle='--', alpha=0.5, linewidth=0.8, zorder=0)
ax1.legend(fontsize=12)

# Bottom Subplot: Residuals
ax2.scatter(zspec_45, eazy_err, alpha=0.7, c='#E75480', s=20,edgecolor='k')
ax2.axhline(0, color='k', linestyle='--', alpha=0.3)

ax2.set_xlabel(r"$z_{spec}$",fontsize=18)
ax2.set_ylabel(r"$\delta z$",fontsize=18)

# Enable minor ticks and set ticks all around
ax2.minorticks_on()
ax2.tick_params(axis='both', which='both', direction='in', top=True, right=True, labelsize=10)
ax2.grid(True, linestyle='--', alpha=0.5, linewidth=0.8, zorder=0)
ax2.set_ylim(-0.3,0.3)
#ax2.legend()
print(f"Average 45K Templates z_phot absolute error: {np.mean(np.abs(eazy_err)):.3e}")
#plt.savefig('/home/caltech-msanche3/data/results_figures/45k_redshifts.png')
plt.show()
# Out:
# Average 45K Templates z_phot absolute error: 1.924e-02

# %%
import matplotlib.pyplot as plt
import numpy as np

#ADD THIS TO PAPER

x = np.linspace(5.5, 15, 10)
y = np.linspace(5.5, 15, 10)

# Main dataset
zspec_45 = [
    7.95,7.96,8.19,12.48,9.68,6.63,6.33,6.32,6.09,7.04,8.58,6.16,9.43,6.04,
    7.41,10.60,7.12,6.73,7.13,6.71
]
z_phot_45 = [
    8.07,8.08,8.10,13.93,9.43,6.61,6.302,6.36,6.14,7.03,8.69,6.56,9.41,5.75,
    7.47, 10.53, 7.47, 6.75, 7.27, 6.72
]
z_lo_45 = [
    0.087, 0.349, 0.032, 0.605, 0.036, 0.038, 0.041, 0.06, 0.077, 0.071, 0.063, 0.062, 0.08, 0.053,
    0.128, 0.12, 0.121, 0.027, 0.077, 0.071
]
z_hi_45 = [
    0.076, 0.07, 0.093, 0.243, 0.423, 0.066, 0.069, 0.085, 0.022, 0.038, 0.068, 0.041, 0.117, 0.06,
    0.065, 0.12, 0.071, 0.079, 0.096, 0.034
]
err_45 = [z_lo_45,z_hi_45]


# Calculate fractional error
eazy_err = [(zs - zp) / (1 + zs) for zs, zp in zip(zspec_45, z_phot_45)]
print(f"Average Larson Templates z_phot absolute error: {np.mean(np.abs(eazy_err)):.3e}")

fig, (ax1, ax2) = plt.subplots(
    2, 1, 
    figsize=(7, 7), 
    sharex=True, 
    gridspec_kw={'hspace': 0, 'height_ratios': [3, 1]}
)

# Top Subplot: z_phot vs z_spec
ax1.errorbar(zspec_45, z_phot_45, yerr=err_45, fmt='s', label="Larson Templates",c='#E75480', ms=4, elinewidth=1, alpha=0.8,markeredgecolor='k',capsize=4,ecolor='k')
ax1.plot(x, y, alpha=0.3, c='k', linestyle='--', label=r'$z_{phot} = z_{spec}$ line')

ax1.set_xlim(5.5, 15)
ax1.set_ylim(5.5, 15)
ax1.set_ylabel(r'$z_{phot}$')
ax1.set_title(r'Comparison of EAZY redshifts vs. spectroscopic redshifts')

# Enable minor ticks and set ticks all around (top, bottom, left, right)
ax1.minorticks_on()
ax1.tick_params(axis='both', which='both', direction='in', top=True, right=True, labelsize=10)
ax1.grid(True, linestyle='--', alpha=0.5, linewidth=0.8, zorder=0)
ax1.legend()

# Bottom Subplot: Residuals
ax2.scatter(zspec_45, eazy_err, alpha=0.7, c='#E75480', s=20,edgecolor='k')
ax2.axhline(0, color='k', linestyle='--', alpha=0.3)

ax2.set_xlabel(r"$z_{spec}$")
ax2.set_ylabel(r"$\delta z$")
ax2.set_ylim(-.3,.3)
ax2.set_xlim(5.5, 15)

# Enable minor ticks and set ticks all around
ax2.minorticks_on()
ax2.tick_params(axis='both', which='both', direction='in', top=True, right=True, labelsize=10)
ax2.grid(True, linestyle='--', alpha=0.5, linewidth=0.8, zorder=0)
#ax2.legend()
#plt.savefig('/home/caltech-msanche3/data/results_figures/larson_redshifts.png')
plt.show()
# Out:
# Average Larson Templates z_phot absolute error: 1.878e-02

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['text.usetex'] = True

# ADD THIS TO PAPER

x = np.linspace(5.5, 14, 10)
y = np.linspace(5.5, 14, 10)

# Main dataset
zspec_45 = [
    7.95,7.96,8.19,12.48,9.68,6.63,6.33,6.32,6.09,7.04,8.58,6.16,9.43,6.04,
    7.41,10.60,7.12,6.73,7.13,6.71
]
zphot_45 = [
    7.96,8.14,8.06,12.33,9.28,6.59,6.23,6.34,6.05,7.09,8.74,6.52,9.27,6.06,
    7.48, 10.56, 7.30, 6.69, 7.30, 6.83
]
z_lo_45 = [
    0.075, 0.21, 0.081, 0.099, 0.057, 0.023, 0.047, 0.059, 0.056, 0.062, 0.08, 0.035, 0.039, 0.062,
    0.081, 0.063, 0.075, 0.04, 0.07, 0.062
]
z_hi_45 = [
    0.065, 0.074, 0.055, 0.905, 0.084, 0.081, 0.064, 0.048, 0.039, 0.07, 0.087, 0.077, 0.576, 0.116,
    0.075, 0.114, 0.07, 0.064, 0.074, 0.074
]

err_45 = [z_lo_45, z_hi_45]


# Calculate fractional error
eazy_err = [(zs - zp) / (1 + zs) for zs, zp in zip(zspec_45, zphot_45)]


fig, (ax1, ax2) = plt.subplots(
    2, 1, 
    figsize=(7, 7), 
    sharex=True, 
    gridspec_kw={'hspace': 0, 'height_ratios': [3, 1]}
)

# Top Subplot: z_phot vs z_spec
ax1.errorbar(zspec_45, zphot_45, yerr=err_45, fmt='s', c='#E75480', ms=4, elinewidth=1, alpha=0.8, label="Control Templates",markeredgecolor='k',capsize=4,ecolor='k')
ax1.plot(x, y, alpha=0.3, c='k', linestyle='--', label=r'$z_{phot} = z_{spec}$ line')

ax1.set_xlim(5.5, 14)
ax1.set_ylim(5.5, 14)
ax1.set_ylabel(r'$z_{phot}$',fontsize=18)
ax1.set_title(r'Comparison of photometric redshifts vs. spectroscopic redshifts')

# Enable minor ticks and set ticks all around (top, bottom, left, right)
ax1.minorticks_on()
ax1.tick_params(axis='both', which='both', direction='in', top=True, right=True, labelsize=10)
ax1.grid(True, linestyle='--', alpha=0.5, linewidth=0.8, zorder=0)
ax1.legend(fontsize=12)

# Bottom Subplot: Residuals
ax2.scatter(zspec_45, eazy_err, alpha=0.7, c='#E75480', s=20,edgecolor='k')
ax2.axhline(0, color='k', linestyle='--', alpha=0.3)

ax2.set_xlabel(r"$z_{spec}$",fontsize=18)
ax2.set_ylabel(r"$\delta z$",fontsize=18)

# Enable minor ticks and set ticks all around
ax2.minorticks_on()
ax2.tick_params(axis='both', which='both', direction='in', top=True, right=True, labelsize=10)
ax2.grid(True, linestyle='--', alpha=0.5, linewidth=0.8, zorder=0)
ax2.set_ylim(-0.3,0.3)
#ax2.legend()
print(f"Average Control Templates z_phot absolute error: {np.mean(np.abs(eazy_err)):.3e}")
#plt.savefig('/home/caltech-msanche3/data/results_figures/control_redshifts.png')
plt.show()
# Out:
# Average Control Templates z_phot absolute error: 1.391e-02

# %%
from astropy.table import Table
import numpy as np
import matplotlib.pyplot as plt
paths_45k = ['/home/caltech-msanche3/SURF2026/scripts/JADES scripts/45K Fitting/JADES_south_45k_fit_circ_z.zout.fits',
             '/home/caltech-msanche3/SURF2026/scripts/JADES scripts/45K Fitting/JADES_north_45k_fit_circ_z.zout.fits']

all_ids = [
    [13405,14376,27503,96216,107324,127219,131688,131971,132845,135819,165595,169896,265801,318988],
    [1004685,1005591,1026356,1032419,1066336,1089452]
]

paths_control = ['/home/caltech-msanche3/SURF2026/scripts/JADES scripts/Tweak Fitting/JADES_south_control_fit_circ_z.zout.fits',
                 '/home/caltech-msanche3/SURF2026/scripts/JADES scripts/Tweak Fitting/JADES_north_control_fit_circ_z.zout.fits']

mass_45k = []
mass_45k_hi = []
mass_45k_lo = []

mass_control = []
mass_control_hi = []
mass_control_lo = []

# extract 45k properties
for i in range(2):
    data = Table.read(paths_45k[i])
    ids_index = []
    ids = all_ids[i]
    for i in range(len(ids)):
        n = np.where(data['id']==ids[i])[0]
        mass_45k.append(data[n]['mass_p'][0][2])
        mass_45k_hi.append(data[n]['mass_p'][0][3])
        mass_45k_lo.append(data[n]['mass_p'][0][1])



# extract tweak control properties
for i in range(2):
    data = Table.read(paths_control[i])
    ids_index = []
    ids = all_ids[i]
    for i in range(len(ids)):
        n = np.where(data['id']==ids[i])[0]
        mass_control.append(data[n]['mass_p'][0][2])
        mass_control_hi.append(data[n]['mass_p'][0][3])
        mass_control_lo.append(data[n]['mass_p'][0][1])

err_45k = [np.log10(mass_45k)-np.log10(mass_45k_lo),np.log10(mass_45k_hi)-np.log10(mass_45k)]
err_control = [np.log10(mass_control)-np.log10(mass_control_lo),np.log10(mass_control_hi)-np.log10(mass_control)]
delta = np.log10(mass_45k)-np.log10(mass_control)
median_delta = np.median(delta)
print(median_delta)
sigma_nmad = 1.4826 * np.median(np.abs(delta - median_delta))
print(sigma_nmad)

fig,ax = plt.subplots(figsize=(5,5))

#ax.errorbar(np.log10(mass_45k),np.log10(mass_control),xerr=err_45k,yerr=err_control,c='#E75480',fmt='s',ms=5,markeredgecolor='k',capsize=4,ecolor='k')
ax.errorbar(np.log10(mass_control),np.log10(mass_45k),yerr=err_45k,xerr=err_control,c='#E75480',fmt='s',ms=5,markeredgecolor='k',capsize=4,ecolor='k')
ax.plot(np.linspace(6,11,10),np.linspace(6,11,10),c='k',linestyle='--')

ax.minorticks_on()
ax.tick_params(axis='both', which='both', direction='in', top=True, right=True, labelsize=10)
ax.set_ylabel(r'$\log_{10}(\mathrm{M}_{\star}/\mathrm{M}_{\odot})_{\mathrm{45K}}$',fontsize=14)
ax.set_xlabel(r'$\log_{10}(\mathrm{M}_{\star}/\mathrm{M}_{\odot})_{\mathrm{Chabrier}}$',fontsize=14)
ax.set_xlim(7.5,11.4)
ax.set_ylim(6.5,9.2)
ax.text(10.1, 6.7, r"$\Delta_{\mathrm{med}}=-0.735$", fontsize=12)
ax.text(10.1, 6.6, r"$\sigma_{\mathrm{NMAD}}=0.200$", fontsize=12)
#plt.savefig('/home/caltech-msanche3/data/results_figures/mass_comparison.png')
# Out:
# -0.7358193123804622
# 0.200748684615287

# %%
from astropy.table import Table
import numpy as np
import matplotlib.pyplot as plt
paths_45k = ['/home/caltech-msanche3/SURF2026/scripts/JADES scripts/45K Fitting/JADES_south_45k_fit_circ_z.zout.fits',
             '/home/caltech-msanche3/SURF2026/scripts/JADES scripts/45K Fitting/JADES_north_45k_fit_circ_z.zout.fits']

all_ids = [
    [13405,14376,27503,96216,107324,127219,131688,131971,132845,135819,165595,169896,265801,318988],
    [1004685,1005591,1026356,1032419,1066336,1089452]
]

paths_control = ['/home/caltech-msanche3/SURF2026/scripts/JADES scripts/Tweak Fitting/JADES_south_control_fit_circ_z.zout.fits',
                 '/home/caltech-msanche3/SURF2026/scripts/JADES scripts/Tweak Fitting/JADES_north_control_fit_circ_z.zout.fits']

sfr_45k = []
sfr_45k_hi = []
sfr_45k_lo = []

sfr_control = []
sfr_control_hi = []
sfr_control_lo = []

print(data.colnames)

# extract 45k properties
for i in range(2):
    data = Table.read(paths_45k[i])
    ids_index = []
    ids = all_ids[i]
    for i in range(len(ids)):
        n = np.where(data['id']==ids[i])[0]
        sfr_45k.append(data[n]['sfr_p'][0][2])
        sfr_45k_hi.append(data[n]['sfr_p'][0][3])
        sfr_45k_lo.append(data[n]['sfr_p'][0][1])



# extract tweak control properties
for i in range(2):
    data = Table.read(paths_control[i])
    ids_index = []
    ids = all_ids[i]
    for i in range(len(ids)):
        n = np.where(data['id']==ids[i])[0]
        sfr_control.append(data[n]['sfr_p'][0][2])
        sfr_control_hi.append(data[n]['sfr_p'][0][3])
        sfr_control_lo.append(data[n]['sfr_p'][0][1])

err_45k = [np.log10(sfr_45k)-np.log10(sfr_45k_lo),np.log10(sfr_45k_hi)-np.log10(sfr_45k)]
err_control = [np.log10(sfr_control)-np.log10(sfr_control_lo),np.log10(sfr_control_hi)-np.log10(sfr_control)]
delta = np.log10(sfr_45k)-np.log10(sfr_control)
median_delta = np.median(delta)
print(median_delta)
sigma_nmad = 1.4826 * np.median(np.abs(delta - median_delta))
print(sigma_nmad)

fig,ax = plt.subplots(figsize=(5,5))

ax.errorbar(np.log10(sfr_control),np.log10(sfr_45k),yerr=err_45k,xerr=err_control,c='#E75480',fmt='s',ms=5,markeredgecolor='k',capsize=4,ecolor='k')
ax.plot(np.linspace(-1,1.5,10),np.linspace(-1,1.5,10),c='k',linestyle='--')

ax.minorticks_on()
ax.tick_params(axis='both', which='both', direction='in', top=True, right=True, labelsize=10)
ax.set_ylabel(r'$\log_{10}[\mathrm{SFR}/ (\mathrm{M}_{\odot}\mathrm{yr}^{-1})]_{\mathrm{45K}}$',fontsize=14)
ax.set_xlabel(r'$\log_{10}[\mathrm{SFR}/ (\mathrm{M}_{\odot}\mathrm{yr}^{-1})]_{\mathrm{Chabrier}}$',fontsize=14)
#ax.set_xlim(7.5,11.4)
ax.set_ylim(-1,1)
ax.text(.7,-.8, r"$\Delta_{\mathrm{med}}=-0.293$", fontsize=12)
ax.text(.7,-.9, r"$\sigma_{\mathrm{NMAD}}=0.203$", fontsize=12)
#plt.savefig('/home/caltech-msanche3/data/results_figures/sfr_comparison.png')
# Out:
# ['id', 'ra', 'dec', 'nusefilt', 'z_ml', 'z_ml_chi2', 'z_ml_risk', 'lc_min', 'lc_max', 'z_phot', 'z_phot_chi2', 'z_phot_risk', 'z_min_risk', 'min_risk', 'z_raw_chi2', 'raw_chi2', 'z025', 'z160', 'z500', 'z840', 'z975', 'restU', 'restU_err', 'restB', 'restB_err', 'restV', 'restV_err', 'restJ', 'restJ_err', 'dL', 'Lv', 'mass', 'sfr', 'LIR', 'energy_abs', 'Av', 'lw_age_V', 'MLv', 'Lv_p', 'mass_p', 'LIR_p', 'sfr_p', 'Av_p', 'ssfr_p']
# -0.29363211564394137
# 0.2037142096257714

# %%
import warnings
warnings.filterwarnings('ignore')
'''
paths = [
    '/home/caltech-msanche3/data/south_spectra/hlsp_jades_jwst_nirspec_goods-s-mediumjwst-166539_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/south_spectra/hlsp_jades_jwst_nirspec_goods-s-ultradeep-96216_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/south_spectra/hlsp_jades_jwst_nirspec_goods-s-deephst-135819_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/south_spectra/hlsp_jades_jwst_nirspec_goods-s-deephst-131688_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/south_spectra/hlsp_jades_jwst_nirspec_goods-s-deephst-127219_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/south_spectra/hlsp_jades_jwst_nirspec_goods-s-mediumjwst-27503_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/south_spectra/hlsp_jades_jwst_nirspec_goods-s-deephst-140125_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/south_spectra/hlsp_jades_jwst_nirspec_goods-s-deepjwst-318988_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/south_spectra/hlsp_jades_jwst_nirspec_goods-s-deephst-131971_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/south_spectra/hlsp_jades_jwst_nirspec_goods-s-deephst-107324_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/south_spectra/hlsp_jades_jwst_nirspec_goods-s-ultradeep-265801_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/south_spectra_out/hlsp_jades_jwst_nirspec_goods-s-deepjwst-14376_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/south_spectra_out/hlsp_jades_jwst_nirspec_goods-s-mediumjwst-169896_clear-prism_v1.0_x1d.fits'
]
plt.rcParams['text.usetex'] = True
ylims = [.6e-19,1.5e-21,.75e-20,2.75e-20,.8e-20,2e-20,.75e-20,2e-20,7e-21,.4e-20,1e-20,3e-21,1.5e-20]

for i in range(len(ids)):
    data = Table.read(paths[i])
    wave_obs = data['WAVELENGTH']
    flux_obs = data['FLUX']
    err_obs = data['FLUX_ERR']

    fig,ax = plt.subplots(figsize=(10,5))
    ax.minorticks_on()
    ax.tick_params(axis='both', which='both', labelsize=16, direction='in', top=True, right=True)
    #ax.plot(wave_obs,flux_obs/err_obs)
    ax.plot(wave_obs,flux_obs)
    #ax.set_title(f'ID: {ids[i]}, avg SNR: {np.mean(flux_obs/err_obs)}')
    ax.set_title(f'DR5 OBJID: {ids[i]}')
    ax.set_xlabel(r'$\lambda ~[\mu m]$',fontsize=18)
    ax.set_ylabel(r'$f_{\lambda} ~(erg (s ~cm^2 ~\mathrm{\AA})^{-1})$',fontsize=18)
    ax.set_ylim(0,ylims[i])
'''
# Out:
# <>:35: SyntaxWarning: invalid escape sequence '\l'
# <>:35: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_259073/1269287001.py:35: SyntaxWarning: invalid escape sequence '\l'
#   ax.set_xlabel(r'$\lambda ~[\mu m]$',fontsize=18)
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
'''
paths = [
    '/home/caltech-msanche3/data/north_spectra/hlsp_jades_jwst_nirspec_goods-n-mediumhst-1009077_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/north_spectra/hlsp_jades_jwst_nirspec_goods-n-mediumhst-1028761_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/north_spectra/hlsp_jades_jwst_nirspec_goods-n-mediumhst-1026356_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/north_spectra/hlsp_jades_jwst_nirspec_goods-n-mediumjwst-1066336_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/north_spectra/hlsp_jades_jwst_nirspec_goods-n-mediumhst-1032419_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/north_spectra/hlsp_jades_jwst_nirspec_goods-n-mediumhst-1005591_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/north_spectra/hlsp_jades_jwst_nirspec_goods-n-mediumjwst-1004685_clear-prism_v1.0_x1d.fits'
]
plt.rcParams['text.usetex'] = True
ylims = [.3e-19,2e-20,1e-20,1e-20,3e-20,2e-20,1e-20]

for i in range(len(ids)):
    data = Table.read(paths[i])
    wave_obs = data['WAVELENGTH']
    flux_obs = data['FLUX']
    err_obs = data['FLUX_ERR']

    fig,ax = plt.subplots(figsize=(10,5))
    ax.minorticks_on()
    ax.tick_params(axis='both', which='both', labelsize=16, direction='in', top=True, right=True)
    #ax.plot(wave_obs,flux_obs/err_obs)
    ax.plot(wave_obs,flux_obs)
    #ax.set_title(f'ID: {ids[i]}, avg SNR: {np.mean(flux_obs/err_obs)}')
    ax.set_title(f'DR5 OBJID: {ids[i]}')
    ax.set_xlabel(r'$\lambda ~[\mu m]$',fontsize=18)
    ax.set_ylabel(r'$f_{\lambda} ~(erg (s ~cm^2 ~\mathrm{\AA})^{-1})$',fontsize=18)
    ax.set_ylim(0,ylims[i])
'''
# Out:
# "\npaths = [\n    '/home/caltech-msanche3/data/north_spectra/hlsp_jades_jwst_nirspec_goods-n-mediumhst-1009077_clear-prism_v1.0_x1d.fits',\n    '/home/caltech-msanche3/data/north_spectra/hlsp_jades_jwst_nirspec_goods-n-mediumhst-1028761_clear-prism_v1.0_x1d.fits',\n    '/home/caltech-msanche3/data/north_spectra/hlsp_jades_jwst_nirspec_goods-n-mediumhst-1026356_clear-prism_v1.0_x1d.fits',\n    '/home/caltech-msanche3/data/north_spectra/hlsp_jades_jwst_nirspec_goods-n-mediumjwst-1066336_clear-prism_v1.0_x1d.fits',\n    '/home/caltech-msanche3/data/north_spectra/hlsp_jades_jwst_nirspec_goods-n-mediumhst-1032419_clear-prism_v1.0_x1d.fits',\n    '/home/caltech-msanche3/data/north_spectra/hlsp_jades_jwst_nirspec_goods-n-mediumhst-1005591_clear-prism_v1.0_x1d.fits',\n    '/home/caltech-msanche3/data/north_spectra/hlsp_jades_jwst_nirspec_goods-n-mediumjwst-1004685_clear-prism_v1.0_x1d.fits'\n]\nplt.rcParams['text.usetex'] = True\nylims = [.3e-19,2e-20,1e-20,1e-20,3e-20,2e-20,1e-20]\n\nfor i 
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.table import Table
import warnings

warnings.filterwarnings('ignore')

# Combine all 20 paths
paths = [
    # South spectra (13 objects)
    '/home/caltech-msanche3/data/south_spectra/hlsp_jades_jwst_nirspec_goods-s-mediumjwst-166539_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/south_spectra/hlsp_jades_jwst_nirspec_goods-s-ultradeep-96216_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/south_spectra/hlsp_jades_jwst_nirspec_goods-s-deephst-135819_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/south_spectra/hlsp_jades_jwst_nirspec_goods-s-deephst-131688_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/south_spectra/hlsp_jades_jwst_nirspec_goods-s-deephst-127219_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/south_spectra/hlsp_jades_jwst_nirspec_goods-s-mediumjwst-27503_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/south_spectra/hlsp_jades_jwst_nirspec_goods-s-deephst-140125_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/south_spectra/hlsp_jades_jwst_nirspec_goods-s-deepjwst-318988_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/south_spectra/hlsp_jades_jwst_nirspec_goods-s-deephst-131971_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/south_spectra/hlsp_jades_jwst_nirspec_goods-s-deephst-107324_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/south_spectra/hlsp_jades_jwst_nirspec_goods-s-ultradeep-265801_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/south_spectra_out/hlsp_jades_jwst_nirspec_goods-s-deepjwst-14376_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/south_spectra_out/hlsp_jades_jwst_nirspec_goods-s-mediumjwst-169896_clear-prism_v1.0_x1d.fits',
    # North spectra (7 objects)
    '/home/caltech-msanche3/data/north_spectra/hlsp_jades_jwst_nirspec_goods-n-mediumhst-1009077_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/north_spectra/hlsp_jades_jwst_nirspec_goods-n-mediumhst-1028761_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/north_spectra/hlsp_jades_jwst_nirspec_goods-n-mediumhst-1026356_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/north_spectra/hlsp_jades_jwst_nirspec_goods-n-mediumjwst-1066336_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/north_spectra/hlsp_jades_jwst_nirspec_goods-n-mediumhst-1032419_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/north_spectra/hlsp_jades_jwst_nirspec_goods-n-mediumhst-1005591_clear-prism_v1.0_x1d.fits',
    '/home/caltech-msanche3/data/north_spectra/hlsp_jades_jwst_nirspec_goods-n-mediumjwst-1004685_clear-prism_v1.0_x1d.fits'
]

ids_all = [
    166539, 96216, 135819, 131688, 127219, 27503, 140125, 318988, 131971, 107324, 265801, 14376, 169896,
    1009077, 1028761, 1026356, 1066336, 1032419, 1005591, 1004685
]

# Combine all 20 y-limits
ylims = [
    .6e-19, 1.5e-21, .75e-20, 2.75e-20, .8e-20, 2e-20, .75e-20, 2e-20, 7e-21, .4e-20, 1e-20, 3e-21, 1.5e-20, # South
    .3e-19, 2e-20, 1e-20, 1e-20, 3e-20, 2e-20, 1e-20 # North
]

plt.rcParams['text.usetex'] = True

# 5 rows by 4 columns figure layout with shared axes
fig, axes = plt.subplots(5, 4, figsize=(20, 9), sharex=True)
axes = axes.flatten()

# Text box formatting properties
bbox_props = dict(boxstyle="round,pad=0.3", fc="white", ec="black", lw=0.8, alpha=0.85)

for i in range(len(ids_all)):
    data = Table.read(paths[i])
    wave_obs = data['WAVELENGTH']
    flux_obs = data['FLUX']

    ax = axes[i]
    ax.minorticks_on()
    ax.tick_params(axis='both', which='both', labelsize=11, direction='in', top=True, right=True)
    ax.plot(wave_obs, flux_obs, c='#E75480')
    ax.set_ylim(0, ylims[i])

    ax.text(0.5, 0.88, f'DR5 OBJID: {ids_all[i]}', transform=ax.transAxes,
            fontsize=11, ha='center', va='top', bbox=bbox_props)

    # Manage x-axis: labels and ticks only on bottom row (indices 16-19)
    if i >= 16:
        ax.set_xlabel(r'$\lambda ~[\mu m]$', fontsize=14)
    else:
        ax.tick_params(labelbottom=False)

    # Manage y-axis: labels only on left column (indices 0, 4, 8, 12, 16)
    if i % 4 == 0:
        ax.set_ylabel(r'$f_{\lambda} ~(erg (s ~cm^2 ~\mathrm{\AA})^{-1})$', fontsize=10)

# Remove spacing between subplots so they touch directly
plt.subplots_adjust(wspace=.1, hspace=.15)

plt.show()
